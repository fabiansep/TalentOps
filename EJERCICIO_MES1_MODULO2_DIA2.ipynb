# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiansep/TalentOps/blob/main/EJERCICIO_MES1_MODULO2_DIA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import sqlite3
import json

# %% [markdown]
# # Actividad

# %%
ventas_csv = pd.DataFrame({
    'id_venta': range(1, 6),
    'producto': ['Laptop', 'Mouse', 'Teclado', 'Monitor', 'Audífonos'],
    'precio': [1200, 25, 80, 300, 150]
})
ventas_csv.to_csv('ventas.csv', index=False)

# Crear Excel con múltiples hojas
clientes_df = pd.DataFrame({
    'id_cliente': [1, 2, 3],
    'nombre': ['Ana', 'Carlos', 'María'],
    'ciudad': ['Madrid', 'Barcelona', 'Valencia']
})

with pd.ExcelWriter('datos.xlsx') as writer:
    ventas_csv.to_excel(writer, sheet_name='Ventas', index=False)
    clientes_df.to_excel(writer, sheet_name='Clientes', index=False)

# Crear JSON
productos_json = [
    {'id': 101, 'nombre': 'Laptop', 'categoria': 'Electrónica'},
    {'id': 102, 'nombre': 'Mouse', 'categoria': 'Accesorios'}
]
with open('productos.json', 'w') as f:
    json.dump(productos_json, f)

# Crear base de datos SQLite
conn = sqlite3.connect('ventas.db')
pedidos_df = pd.DataFrame({
    'id_pedido': [1, 2, 3],
    'id_cliente': [1, 2, 1],
    'fecha': ['2024-01-15', '2024-01-16', '2024-01-17'],
    'total': [1225, 25, 380]
})
pedidos_df.to_sql('pedidos', conn, index=False, if_exists='replace')
conn.close()

# %%
df_csv = pd.read_csv('ventas.csv')
print("Desde CSV:")
print(df_csv.head())

# Desde Excel (hoja específica)
df_excel_ventas = pd.read_excel('datos.xlsx', sheet_name='Ventas')
df_excel_clientes = pd.read_excel('datos.xlsx', sheet_name='Clientes')
print("\nDesde Excel - Ventas:")
print(df_excel_ventas.head())

# Desde JSON
df_json = pd.read_json('productos.json')
print("\nDesde JSON:")
print(df_json)

# Desde SQLite
conn = sqlite3.connect('ventas.db')
df_sql = pd.read_sql('SELECT * FROM pedidos', conn)
conn.close()
print("\nDesde SQLite:")
print(df_sql)
# Out:
# Desde CSV:
#    id_venta   producto  precio
# 0         1     Laptop    1200
# 1         2      Mouse      25
# 2         3    Teclado      80
# 3         4    Monitor     300
# 4         5  Audífonos     150
#
# Desde Excel - Ventas:
#    id_venta   producto  precio
# 0         1     Laptop    1200
# 1         2      Mouse      25
# 2         3    Teclado      80
# 3         4    Monitor     300
# 4         5  Audífonos     150
#
# Desde JSON:
#     id  nombre    categoria
# 0  101  Laptop  Electrónica
# 1  102   Mouse   Accesorios
#
# Desde SQLite:
#    id_pedido  id_cliente       fecha  total
# 0          1           1  2024-01-15   1225
# 1          2           2  2024-01-16     25
# 2          3           1  2024-01-17    380

# %% [markdown]
# # Obtención de datos a través de API

# %%
URL = 'https://api.mercadopublico.cl/servicios/v1/Publico/Empresas/BuscarComprador?ticket=F8537A18-6766-4DEF-9E59-426B4FEE2844'
HEADERS = {'Accept': 'application/json'}

# %%
r = requests.get(url = URL, headers=HEADERS)

data = r.json()
df_empresas = pd.DataFrame(data['listaEmpresas'])

# Ver el resultado
print(df_empresas)
# Out:
#     CodigoEmpresa                                      NombreEmpresa
# 0            7086  AGENCIA CHILENA DE COOPERACION INTERNACIONAL P...
# 1         1224636           AGENCIA CHILENA DE EFICIENCIA ENERGETICA
# 2            7193    AGENCIA DE PROMOCION DE LA INVERSION EXTRANJERA
# 3            7212                   Agencia Nacional de Inteligencia
# 4         1824441  ASOCIACION DE MUNICIPIOS METROPOLITANOS PARA L...
# ..            ...                                                ...
# 895         96996                          UNIVERSIDAD DE VALPARAISO
# 896         99805                            UNIVERSIDAD DEL BIO BIO
# 897        164268  UNIVERSIDAD METROPOLITANA DE CIENCIAS DE LA ED...
# 898        126109              UNIVERSIDAD TECNOLOGICA METROPOLITANA
# 899          7438                             Zona Franca de Iquique
#
# [900 rows x 2 columns]

# %%
data
# Out:
# {'Cantidad': 900,
#  'FechaCreacion': '2025-11-11T11:03:35.0368512Z',
#  'listaEmpresas': [{'CodigoEmpresa': '7086',
#    'NombreEmpresa': 'AGENCIA CHILENA DE COOPERACION INTERNACIONAL PARA EL DESARROLLO'},
#   {'CodigoEmpresa': '1224636',
#    'NombreEmpresa': 'AGENCIA CHILENA DE EFICIENCIA ENERGETICA'},
#   {'CodigoEmpresa': '7193',
#    'NombreEmpresa': 'AGENCIA DE PROMOCION DE LA INVERSION EXTRANJERA'},
#   {'CodigoEmpresa': '7212',
#    'NombreEmpresa': 'Agencia Nacional de Inteligencia'},
#   {'CodigoEmpresa': '1824441',
#    'NombreEmpresa': 'ASOCIACION DE MUNICIPIOS METROPOLITANOS PARA LA SEGURIDAD CIUDADANA'},
#   {'CodigoEmpresa': '1806837',
#    'NombreEmpresa': 'Asociación para el desarrollo productivo del turismo Alto del Carmen'},
#   {'CodigoEmpresa': '6959', 'NombreEmpresa': 'Banco del Estado de Chile'},
#   {'CodigoEmpresa': '7265',
#    'NombreEmpresa': 'Biblioteca del Congreso Nacional'},
#   {'CodigoEmpresa': '7038', 'NombreEmpresa': 'Bienestar del Registro Civil'},
#   {'CodigoEmpresa': '7313', 'NombreEmpresa': 'C.D.T. Doctora Eloisa Díaz'},
#   {'CodigoEmpresa': '7175',
#    'NombreEmpresa': 'CAJA DE PREVISION DE LA DEFENSA NACIONAL'},
#   {'CodigoEmpresa': '156657', 'NombreEmpresa': 'Cámara de Diputados de Chile'},
#   {'CodigoEmpresa': '7198', 'NombreEmpresa': 'Casa de Moneda de Chile'},
#   {'CodigoEmpresa': '6957',
#    'NombreEmpresa': 'CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD'},
#   {'CodigoEmpresa': '1339711',
#    'NombreEmpresa': 'CENTRO ASISTENCIAL NORTE DE ANTOFAGASTA'},
#   {'CodigoEmpresa': '1741046',
#    'NombreEmpresa': 'CENTRO DE FORMACION TECNICA DE LA REGION DE ATACAMA'},
#   {'CodigoEmpresa': '1796821',
#    'NombreEmpresa': 'CENTRO DE FORMACIÓN TÉCNICA ESTATAL DE LA REGIÓN DEL BIOBÍO'},
#   {'CodigoEmpresa': '1772424',
#    'NombreEmpresa': 'CENTRO DE FORMACIÓN TÉCNICA ESTATAL DE LA REGIÓN DEL LIBERTADOR GENERA'},
#   {'CodigoEmpresa': '1700248',
#    'NombreEmpresa': 'CENTRO DE FORMACION TECNICA ESTATAL DE MAGALLANES Y ANTARTICA CHILENA'},
#   {'CodigoEmpresa': '1741019',
#    'NombreEmpresa': 'CENTRO DE FORMACIÓN TÉCNICA ESTATAL REGIÓN ARICA Y PARINACOTA'},
#   {'CodigoEmpresa': '7380',
#    'NombreEmpresa': 'CENTRO DE INFORMACION DE RECURSOS NATURALES'},
#   {'CodigoEmpresa': '7317',
#    'NombreEmpresa': 'CENTRO DE REFERENCIA DE SALUD DE MAIPU'},
#   {'CodigoEmpresa': '7136',
#    'NombreEmpresa': 'CENTRO DE REFERENCIA DE SALUD DE PENALOLEN CORDILLERA ORIENTE'},
#   {'CodigoEmpresa': '7461',
#    'NombreEmpresa': 'Centro Diagnóstico Terapéutico Los Angeles'},
#   {'CodigoEmpresa': '7373',
#    'NombreEmpresa': 'CENTRO REFERENCIAL DE SALUD DR SALVADOR ALLENDE GOSSENS'},
#   {'CodigoEmpresa': '111870', 'NombreEmpresa': 'COMANDO DE APOYO A LA FUERZA'},
#   {'CodigoEmpresa': '192032',
#    'NombreEmpresa': 'COMISION ADMINISTRADORA DEL SISTEMA DE CREDITOS P. ESTUDIOS SUPERIORES'},
#   {'CodigoEmpresa': '7219',
#    'NombreEmpresa': 'Comisión Chilena de Energía Nuclear'},
#   {'CodigoEmpresa': '7075',
#    'NombreEmpresa': 'Comisión Chilena del Cobre - COCHILCO'},
#   {'CodigoEmpresa': '262897',
#    'NombreEmpresa': 'COMISION NACIONAL DE ACREDITACION'},
#   {'CodigoEmpresa': '6938', 'NombreEmpresa': 'Comisión Nacional de Energía'},
#   {'CodigoEmpresa': '7213',
#    'NombreEmpresa': 'Comisión Nacional de Investigación Científica y Tecnológicas - CONICYT'},
#   {'CodigoEmpresa': '7186', 'NombreEmpresa': 'COMISION NACIONAL DE RIEGO'},
#   {'CodigoEmpresa': '7016',
#    'NombreEmpresa': 'COMISION PARA EL MERCADO FINANCIERO'},
#   {'CodigoEmpresa': '7043', 'NombreEmpresa': 'Comité de Seguros del Agro'},
#   {'CodigoEmpresa': '7057', 'NombreEmpresa': 'Comité SEP'},
#   {'CodigoEmpresa': '7320',
#    'NombreEmpresa': 'COMPLEJO ASISTENCIAL DR. SOTERO DEL RIO'},
#   {'CodigoEmpresa': '7375',
#    'NombreEmpresa': 'COMPLEJO ASISTENCIAL DR.VICTOR RIOS RUIZ'},
#   {'CodigoEmpresa': '7103',
#    'NombreEmpresa': 'Complejo Penitenciario de Valparaiso'},
#   {'CodigoEmpresa': '1090137',
#    'NombreEmpresa': 'CONGREGACIÓN HIJAS DE SANTA MARIA DE LA PROVIDENCIA'},
#   {'CodigoEmpresa': '6933', 'NombreEmpresa': 'Consejo de Defensa del Estado'},
#   {'CodigoEmpresa': '7224',
#    'NombreEmpresa': 'Consejo de Rectores de las Universidades Chilenas'},
#   {'CodigoEmpresa': '1692048', 'NombreEmpresa': 'CONSEJO FISCAL AUTONOMO'},
#   {'CodigoEmpresa': '7082', 'NombreEmpresa': 'CONSEJO NACIONAL DE EDUCACION'},
#   {'CodigoEmpresa': '1060064',
#    'NombreEmpresa': 'CONSEJO PARA LA TRANSPARENCIA'},
#   {'CodigoEmpresa': '118627',
#    'NombreEmpresa': 'CONSULTORIO GENERAL URBANO DR ALEJANDRO GUTIERREZ'},
#   {'CodigoEmpresa': '118630',
#    'NombreEmpresa': 'CONSULTORIO GENERAL URBANO VICTOR DOMINGO SILVA'},
#   {'CodigoEmpresa': '7144',
#    'NombreEmpresa': 'CONSULTORIO GENERAL URBANO VIOLETA PARRA'},
#   {'CodigoEmpresa': '7133', 'NombreEmpresa': 'Consultorio Miraflores'},
#   {'CodigoEmpresa': '7231',
#    'NombreEmpresa': 'CONTRALORIA GENERAL DE LA REPUBLICA'},
#   {'CodigoEmpresa': '7342',
#    'NombreEmpresa': 'CORP ADMINISTRATIVA DEL PODER JUDICIAL'},
#   {'CodigoEmpresa': '1812443', 'NombreEmpresa': 'CORP CULTURAL DE OSORNO'},
#   {'CodigoEmpresa': '7235',
#    'NombreEmpresa': 'CORP DE ASISTENCIA JUDICIAL DE LA REGION DE VALPARAISO'},
#   {'CodigoEmpresa': '272303',
#    'NombreEmpresa': 'CORP DE ASISTENCIA JUDICIAL DE LAS REG T'},
#   {'CodigoEmpresa': '1812422',
#    'NombreEmpresa': 'CORP MUNICIP ANCUD PARA LA EDUCAC SALUD'},
#   {'CodigoEmpresa': '1088974',
#    'NombreEmpresa': 'CORP MUNICIPAL DE CASTRO PARA LA EDUCACION SALUD Y ATENCION AL MENOR'},
#   {'CodigoEmpresa': '7058',
#    'NombreEmpresa': 'CORP MUNICIPAL DE DESARROLLO SOCIAL CERRO NAVIA'},
#   {'CodigoEmpresa': '1812146',
#    'NombreEmpresa': 'CORP MUNICIPAL DE DESARROLLO SOCIAL DE CALERA DE TANGO'},
#   {'CodigoEmpresa': '1812426',
#    'NombreEmpresa': 'CORP MUNICIPAL DE DESARROLLO SOCIAL DE NUNOA'},
#   {'CodigoEmpresa': '1800776',
#    'NombreEmpresa': 'CORP MUNICIPAL DE DESARROLLO SOCIAL DE POZO ALMONTE'},
#   {'CodigoEmpresa': '7105',
#    'NombreEmpresa': 'CORP MUNICIPAL DE EDUC SALUD CULTURA Y RECREACION DE LA FLORIDA'},
#   {'CodigoEmpresa': '1800773',
#    'NombreEmpresa': 'CORP MUNICIPAL DE EDUCACION Y SAL'},
#   {'CodigoEmpresa': '7483', 'NombreEmpresa': 'CORP MUNICIPAL DE PANGUIPULLI'},
#   {'CodigoEmpresa': '1035946',
#    'NombreEmpresa': 'CORP MUNICIPAL DE SERVICIOS Y DESARROLLO'},
#   {'CodigoEmpresa': '7183',
#    'NombreEmpresa': 'CORP NACIONAL DE DESARROLLO INDIGENA'},
#   {'CodigoEmpresa': '6924', 'NombreEmpresa': 'CORP NACIONAL FORESTAL'},
#   {'CodigoEmpresa': '1824379',
#    'NombreEmpresa': 'CORPORACION ALDEA DEL ENCUENTRO DE LA REINA'},
#   {'CodigoEmpresa': '1824375',
#    'NombreEmpresa': 'CORPORACION CULTURAL DE LA REINA'},
#   {'CodigoEmpresa': '1814748',
#    'NombreEmpresa': 'CORPORACION CULTURAL DE PENALOLEN'},
#   {'CodigoEmpresa': '1823674',
#    'NombreEmpresa': 'CORPORACION CULTURAL MUNICIPAL DE ANCUD'},
#   {'CodigoEmpresa': '1812451',
#    'NombreEmpresa': 'Corporación Cultural Municipalidad del Maule'},
#   {'CodigoEmpresa': '7354',
#    'NombreEmpresa': 'CORPORACION DE ASISTENCIA JUDICIAL DE LA REGION DEL BIO BIO'},
#   {'CodigoEmpresa': '7152',
#    'NombreEmpresa': 'Corporación de Asistencia Judicial RM'},
#   {'CodigoEmpresa': '1806878',
#    'NombreEmpresa': 'Corporación de Cultura Isla de Maipo'},
#   {'CodigoEmpresa': '1765161',
#    'NombreEmpresa': 'CORPORACION DE DESARROLLO E INNOVACION DE LA ILUSTRE MUNICIPALIDAD DE'},
#   {'CodigoEmpresa': '1085182',
#    'NombreEmpresa': 'Corporación de Ecuación, Salud y Menores de Puerto Natales'},
#   {'CodigoEmpresa': '6942',
#    'NombreEmpresa': 'CORPORACION DE FOMENTO DE LA PRODUCCION'},
#   {'CodigoEmpresa': '1821972',
#    'NombreEmpresa': 'CORPORACION MUNICIPAL  DE DEPORTES  DE SAN CLEMENTE'},
#   {'CodigoEmpresa': '1824396',
#    'NombreEmpresa': 'CORPORACION MUNICIPAL CLUB DE LA REINA SOCIAL DEPORTIVO Y RECREACIONAL'},
#   {'CodigoEmpresa': '1806860',
#    'NombreEmpresa': 'CORPORACION MUNICIPAL DE CULTURA DE SAN JOAQUIN'},
#   {'CodigoEmpresa': '1806052',
#    'NombreEmpresa': 'CORPORACION MUNICIPAL DE CULTURA Y TURISMO DE LA COMUNA DE QUINTERO'},
#   {'CodigoEmpresa': '1809257',
#    'NombreEmpresa': 'Corporación Municipal de Deporte de Salamanca'},
#   {'CodigoEmpresa': '1812754',
#    'NombreEmpresa': 'Corporación Municipal de Deportes de Maule'},
#   {'CodigoEmpresa': '1824391',
#    'NombreEmpresa': 'CORPORACION MUNICIPAL DE DEPORTES Y RECREACION DE LA REINA'},
#   {'CodigoEmpresa': '1812445',
#    'NombreEmpresa': 'CORPORACION MUNICIPAL DE DEPORTES Y RECREACION DE TEMUCO'},
#   {'CodigoEmpresa': '1824403',
#    'NombreEmpresa': 'CORPORACION MUNICIPAL DE DESARROLLO URBANO DE COLINA'},
#   {'CodigoEmpresa': '1033466',
#    'NombreEmpresa': 'CORPORACION MUNICIPAL DE EDUCACION Y SALUD DE SAN BERNARDO'},
#   {'CodigoEmpresa': '1034640',
#    'NombreEmpresa': 'CORPORACION MUNICIPAL DE PENALOLEN PARA EL DESARROLO SOCIAL CORMUP'},
#   {'CodigoEmpresa': '1812428',
#    'NombreEmpresa': 'CORPORACION MUNICIPAL DEL DEPORTE DE LAMPA'},
#   {'CodigoEmpresa': '1812413',
#    'NombreEmpresa': 'CORPORACION MUNICIPAL PARA EL DESARROLLO COMUNAL SOL DE ATACAMA'},
#   {'CodigoEmpresa': '1806867',
#    'NombreEmpresa': 'CORPORACIÓN MUNICIPAL PUEBLITO DE LAS VIZCACHAS'},
#   {'CodigoEmpresa': '1799808', 'NombreEmpresa': 'CORPORACIÓN YUNUS'},
#   {'CodigoEmpresa': '7129', 'NombreEmpresa': 'DEFENSA CIVIL DE CHILE'},
#   {'CodigoEmpresa': '1806732',
#    'NombreEmpresa': 'Defensoría del Contribuyente'},
#   {'CodigoEmpresa': '7034', 'NombreEmpresa': 'DEFENSORIA PENAL PUBLICA'},
#   {'CodigoEmpresa': '7450',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE ARAUCO'},
#   {'CodigoEmpresa': '7059',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE AYSÉN'},
#   {'CodigoEmpresa': '7134',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE CAPITÁN PRAT'},
#   {'CodigoEmpresa': '7387',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE CARDENAL CARO'},
#   {'CodigoEmpresa': '7281',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE CAUQUENES'},
#   {'CodigoEmpresa': '7271',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE CHACABUCO'},
#   {'CodigoEmpresa': '7155',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE CHAÑARAL'},
#   {'CodigoEmpresa': '7499',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE CHILOÉ'},
#   {'CodigoEmpresa': '7286',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE CHOAPA'},
#   {'CodigoEmpresa': '7376',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE COLCHAGUA'},
#   {'CodigoEmpresa': '7284',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE CORDILLERA'},
#   {'CodigoEmpresa': '7263',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE CURICÓ'},
#   {'CodigoEmpresa': '7237',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE EL LOA'},
#   {'CodigoEmpresa': '7309',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE GENERAL CARRERA'},
#   {'CodigoEmpresa': '7150',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE HUASCO'},
#   {'CodigoEmpresa': '135959',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE ISLA DE PASCUA'},
#   {'CodigoEmpresa': '7148',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE LA ANTÁRTICA CHILENA'},
#   {'CodigoEmpresa': '7037',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE LIMARÍ'},
#   {'CodigoEmpresa': '7282',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE LINARES'},
#   {'CodigoEmpresa': '7253',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE MAIPO'},
#   {'CodigoEmpresa': '7275',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE MALLECO'},
#   {'CodigoEmpresa': '1163597',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE MARGA MARGA'},
#   {'CodigoEmpresa': '7056',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE MELIPILLA'},
#   {'CodigoEmpresa': '7283',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE OSORNO'},
#   {'CodigoEmpresa': '7252',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE PALENA'},
#   {'CodigoEmpresa': '7350',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE PARINACOTA'},
#   {'CodigoEmpresa': '7420',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE PETORCA'},
#   {'CodigoEmpresa': '7346',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE QUILLOTA'},
#   {'CodigoEmpresa': '111119',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE SAN ANTONIO'},
#   {'CodigoEmpresa': '7495',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE SAN FELIPE DE ACONCAGUA'},
#   {'CodigoEmpresa': '7055',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE TALAGANTE'},
#   {'CodigoEmpresa': '7381',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE TIERRA DEL FUEGO'},
#   {'CodigoEmpresa': '7063',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE TOCOPILLA'},
#   {'CodigoEmpresa': '7264',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DE ÚLTIMA ESPERANZA'},
#   {'CodigoEmpresa': '7140',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DEL BIOBÍO'},
#   {'CodigoEmpresa': '269793',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DEL RANCO'},
#   {'CodigoEmpresa': '275314',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL PROVINCIAL DEL TAMARUGAL'},
#   {'CodigoEmpresa': '7204',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DE ANTOFAGASTA'},
#   {'CodigoEmpresa': '270727',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DE ARICA Y PARINACOTA'},
#   {'CodigoEmpresa': '7115',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DE ATACAMA'},
#   {'CodigoEmpresa': '7229',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DE AYSÉN DEL GENERAL CARLOS IBÁÑEZ DE'},
#   {'CodigoEmpresa': '7236',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DE COQUIMBO'},
#   {'CodigoEmpresa': '7220',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DE LA ARAUCANÍA'},
#   {'CodigoEmpresa': '7215',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DE LOS LAGOS'},
#   {'CodigoEmpresa': '270726',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DE LOS RÍOS'},
#   {'CodigoEmpresa': '7214',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DE MAGALLANES Y DE LA ANTÁRTICA CHILE'},
#   {'CodigoEmpresa': '7234',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DE TARAPACÁ'},
#   {'CodigoEmpresa': '7196',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DE VALPARAÍSO'},
#   {'CodigoEmpresa': '7226',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DEL BIOBÍO'},
#   {'CodigoEmpresa': '7201',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DEL LIBERTADOR BERNARDO  O´HIGGINS'},
#   {'CodigoEmpresa': '7225',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL DEL MAULE'},
#   {'CodigoEmpresa': '7195',
#    'NombreEmpresa': 'DELEGACIÓN PRESIDENCIAL REGIONAL METROPOLITANA DE SANTIAGO'},
#   {'CodigoEmpresa': '7299', 'NombreEmpresa': 'Departamento de Salud Parral'},
#   {'CodigoEmpresa': '7228',
#    'NombreEmpresa': 'Dirección Administrativa - Min. Defensa'},
#   {'CodigoEmpresa': '111875',
#    'NombreEmpresa': 'DIRECCION DE ABASTECIMIENTO DE LA ARMADA'},
#   {'CodigoEmpresa': '6945',
#    'NombreEmpresa': 'DIRECCION DE COMPRAS Y CONTRATACION PUBLICA'},
#   {'CodigoEmpresa': '113812',
#    'NombreEmpresa': 'DIRECCION DE LOGISTICA DE CARABINEROS'},
#   {'CodigoEmpresa': '7012',
#    'NombreEmpresa': 'DIRECCION DE PRESUPUESTOS MINISTERIO DE'},
#   {'CodigoEmpresa': '7010',
#    'NombreEmpresa': 'Dirección de Relaciones Económicas'},
#   {'CodigoEmpresa': '7000', 'NombreEmpresa': 'DIRECCION DEL TRABAJO'},
#   {'CodigoEmpresa': '7202',
#    'NombreEmpresa': 'DIRECCION GENERAL DE AERONAUTICA CIVIL'},
#   {'CodigoEmpresa': '6925',
#    'NombreEmpresa': 'DIRECCION GENERAL DE GENDARMERIA DE CHIL'},
#   {'CodigoEmpresa': '7127',
#    'NombreEmpresa': 'DIRECCION GENERAL DE MOVILIZACIONN NACIONAL'},
#   {'CodigoEmpresa': '1674056',
#    'NombreEmpresa': 'DIRECCION GENERAL DE PROMOCION DE EXPORTACIONES'},
#   {'CodigoEmpresa': '7209',
#    'NombreEmpresa': 'DIRECCION GENERAL DEL CREDITO PRENDARIO'},
#   {'CodigoEmpresa': '7187',
#    'NombreEmpresa': 'Dirección Nacional de Fronteras y Límites del Estado'},
#   {'CodigoEmpresa': '7371',
#    'NombreEmpresa': 'DIRECCION NACIONAL DEL SERVICIO CIVIL'},
#   {'CodigoEmpresa': '6927',
#    'NombreEmpresa': 'DIRECCION PREVISION DE CARABINEROS DE CHILE'},
#   {'CodigoEmpresa': '118628', 'NombreEmpresa': 'DIRECCION SALUD RURAL'},
#   {'CodigoEmpresa': '7295',
#    'NombreEmpresa': 'DIRECCION SERVICIO DE SALUD TALCAHUANO'},
#   {'CodigoEmpresa': '7272',
#    'NombreEmpresa': 'DIRECCION SERVICIO SALUD METROPOLITANO O'},
#   {'CodigoEmpresa': '7491',
#    'NombreEmpresa': 'DR. VICTOR HUGO MOLL DE CABILDO'},
#   {'CodigoEmpresa': '7208',
#    'NombreEmpresa': 'Empresa de Abastecimiento de Zonas Aisladas- EMAZA'},
#   {'CodigoEmpresa': '7467',
#    'NombreEmpresa': 'Empresa de Servicios Sanitarios de Atacama'},
#   {'CodigoEmpresa': '7128',
#    'NombreEmpresa': 'Empresa de Servicios Sanitarios de la Araucania'},
#   {'CodigoEmpresa': '7358',
#    'NombreEmpresa': 'Empresa de Servicios Sanitarios de Magallanes S.A.'},
#   {'CodigoEmpresa': '7138',
#    'NombreEmpresa': 'Empresa de Servicios Sanitarios de Tarapacá S.A.'},
#   {'CodigoEmpresa': '7074',
#    'NombreEmpresa': 'EMPRESA DE TRANSPORTE DE PASAJEROS METRO S A'},
#   {'CodigoEmpresa': '6961', 'NombreEmpresa': 'Empresa Nacional de Minería'},
#   {'CodigoEmpresa': '7149', 'NombreEmpresa': 'Empresa Nacional del Petróleo'},
#   {'CodigoEmpresa': '1069779',
#    'NombreEmpresa': 'EMPRESA PORTUARIA ANTOFAGASTA'},
#   {'CodigoEmpresa': '1085179', 'NombreEmpresa': 'Empresa Portuaria Arica'},
#   {'CodigoEmpresa': '7493', 'NombreEmpresa': 'EMPRESA PORTUARIA IQUIQUE'},
#   {'CodigoEmpresa': '7463', 'NombreEmpresa': 'Empresa Portuaria Puerto Montt'},
#   {'CodigoEmpresa': '1076044',
#    'NombreEmpresa': 'EMPRESA PORTUARIA SAN ANTONIO'},
#   {'CodigoEmpresa': '1061586',
#    'NombreEmpresa': 'EMPRESA PORTUARIA VALPARAISO'},
#   {'CodigoEmpresa': '7266', 'NombreEmpresa': 'ESTADO MAYOR CONJUNTO'},
#   {'CodigoEmpresa': '7076', 'NombreEmpresa': 'FISCALIA NACIONAL ECONOMICA'},
#   {'CodigoEmpresa': '7182',
#    'NombreEmpresa': 'FONDO DE SOLIDARIDAD E INVERSION SOCIAL'},
#   {'CodigoEmpresa': '220665',
#    'NombreEmpresa': 'FONDO HOSPITAL DE LA DIRECCION DE PREVISION DE CARABINEROS DE CHILE'},
#   {'CodigoEmpresa': '6954', 'NombreEmpresa': 'FONDO NACIONAL DE SALUD'},
#   {'CodigoEmpresa': '6946',
#    'NombreEmpresa': 'FUERZA AEREA DE CHILE COMANDO LOGISTICO'},
#   {'CodigoEmpresa': '1090451',
#    'NombreEmpresa': 'FUND NACIONAL DE ORQUESTAS JUVENILES E INFANTILES DE CHILE'},
#   {'CodigoEmpresa': '1824436', 'NombreEmpresa': 'FUNDACION CLUB PROVIDENCIA'},
#   {'CodigoEmpresa': '1824423',
#    'NombreEmpresa': 'FUNDACION MUNICIPAL DE CULTURA DE PROVIDENCIA'},
#   {'CodigoEmpresa': '1736867',
#    'NombreEmpresa': 'Fundación para la Innovación Agraria'},
#   {'CodigoEmpresa': '1857193',
#    'NombreEmpresa': 'FUNDACION TEATRO MUNICIPAL DE LAS CONDES'},
#   {'CodigoEmpresa': '7061', 'NombreEmpresa': 'GOBERNACION DE CAUTIN'},
#   {'CodigoEmpresa': '7347', 'NombreEmpresa': 'Gobernación Provincia de Elqui'},
#   {'CodigoEmpresa': '7357',
#    'NombreEmpresa': 'Gobernación Provincial de Arica'},
#   {'CodigoEmpresa': '7379',
#    'NombreEmpresa': 'GOBERNACION PROVINCIAL DE CACHAPOAL'},
#   {'CodigoEmpresa': '7300',
#    'NombreEmpresa': 'Gobernación Provincial de Concepción'},
#   {'CodigoEmpresa': '7145',
#    'NombreEmpresa': 'Gobernación Provincial de Copiapó'},
#   {'CodigoEmpresa': '7292',
#    'NombreEmpresa': 'GOBERNACION PROVINCIAL DE COYHAIQUE'},
#   {'CodigoEmpresa': '7349',
#    'NombreEmpresa': 'GOBERNACION PROVINCIAL DE IQUIQUE'},
#   {'CodigoEmpresa': '7267',
#    'NombreEmpresa': 'Gobernación Provincial de Llanquihue'},
#   {'CodigoEmpresa': '7009',
#    'NombreEmpresa': 'GOBERNACION PROVINCIAL DE LOS ANDES'},
#   {'CodigoEmpresa': '7484',
#    'NombreEmpresa': 'GOBERNACION PROVINCIAL DE MAGALLANES'},
#   {'CodigoEmpresa': '7142',
#    'NombreEmpresa': 'Gobernación Provincial de Ñuble'},
#   {'CodigoEmpresa': '7269',
#    'NombreEmpresa': 'GOBERNACION PROVINCIAL DE TALCA'},
#   {'CodigoEmpresa': '7322',
#    'NombreEmpresa': 'GOBERNACION PROVINCIAL DE VALDIVIA'},
#   {'CodigoEmpresa': '7352',
#    'NombreEmpresa': 'GOBERNACION PROVINCIAL DE VALPARAISO'},
#   {'CodigoEmpresa': '7199',
#    'NombreEmpresa': 'GOBIERNO REGIONAL DE ANTOFAGASTA'},
#   {'CodigoEmpresa': '267965',
#    'NombreEmpresa': 'GOBIERNO REGIONAL DE ARICA-PARINACOTA'},
#   {'CodigoEmpresa': '7077', 'NombreEmpresa': 'GOBIERNO REGIONAL DE ATACAMA'},
#   {'CodigoEmpresa': '7085', 'NombreEmpresa': 'GOBIERNO REGIONAL DE AYSEN'},
#   {'CodigoEmpresa': '7013',
#    'NombreEmpresa': 'GOBIERNO REGIONAL DE LA ARAUCANIA'},
#   {'CodigoEmpresa': '7015',
#    'NombreEmpresa': 'GOBIERNO REGIONAL DE LA REGION DEL BIO BIO'},
#   {'CodigoEmpresa': '267799',
#    'NombreEmpresa': 'GOBIERNO REGIONAL DE LOS RIOS'},
#   {'CodigoEmpresa': '7084', 'NombreEmpresa': 'GOBIERNO REGIONAL DE TARAPACA'},
#   {'CodigoEmpresa': '7207',
#    'NombreEmpresa': 'GOBIERNO REGIONAL DECIMA REGION LOS LAGOS'},
#   {'CodigoEmpresa': '6940',
#    'NombreEmpresa': 'GOBIERNO REGIONAL IV REGION COQUIMBO'},
#   {'CodigoEmpresa': '7222',
#    'NombreEmpresa': 'GOBIERNO REGIONAL REGION METROPOLITANA'},
#   {'CodigoEmpresa': '7172', 'NombreEmpresa': 'GOBIERNO REGIONAL V REGION'},
#   {'CodigoEmpresa': '7200',
#    'NombreEmpresa': 'GOBIERNO REGIONAL VI REGION DEL LI BERTADOR B O"HIGGINS'},
#   {'CodigoEmpresa': '7223', 'NombreEmpresa': 'GOBIERNO REGIONAL VII REGION'},
#   {'CodigoEmpresa': '7087',
#    'NombreEmpresa': 'GOBIERNO REGIONAL XII REGION MAGALLANES Y ANTARTICA CHILENA'},
#   {'CodigoEmpresa': '103933',
#    'NombreEmpresa': 'Hermanas Misioneras Franciscanas de Purulón'},
#   {'CodigoEmpresa': '7403', 'NombreEmpresa': 'Hospital  Lonquimay'},
#   {'CodigoEmpresa': '7348',
#    'NombreEmpresa': 'HOSPITAL ADRIANA COUSINO DE QUINTERO'},
#   {'CodigoEmpresa': '7393', 'NombreEmpresa': 'HOSPITAL BASE OSORNO'},
#   {'CodigoEmpresa': '7297',
#    'NombreEmpresa': 'HOSPITAL CLINICO DE MAGALLANES DR. LAUTARO NAVARRO AVARIA'},
#   {'CodigoEmpresa': '7042',
#    'NombreEmpresa': 'HOSPITAL CLINICO HERMINDA MARTIN'},
#   {'CodigoEmpresa': '1375151',
#    'NombreEmpresa': 'HOSPITAL CLINICO METROPOLITANO DE LA FLORIDA DOCTORA ELOISA DIAZ'},
#   {'CodigoEmpresa': '1379869',
#    'NombreEmpresa': 'HOSPITAL CLINICO METROPOLITANO EL CARMEN DOCTOR LUIS VALENTIN FERRADA'},
#   {'CodigoEmpresa': '1759990',
#    'NombreEmpresa': 'HOSPITAL COMPLEJO ASISTENCIAL PADRE LAS CASAS'},
#   {'CodigoEmpresa': '7137',
#    'NombreEmpresa': 'HOSPITAL COMUNITARIO DE SALUD FAMILIAR DE BULNES'},
#   {'CodigoEmpresa': '1286160',
#    'NombreEmpresa': 'HOSPITAL DE CASTRO DR. AUGUSTO RIFFART'},
#   {'CodigoEmpresa': '7277', 'NombreEmpresa': 'Hospital de Constitución'},
#   {'CodigoEmpresa': '7486',
#    'NombreEmpresa': 'HOSPITAL DE LA FAMILIA Y LA COMUNIDAD SANTO TOMAS DE LIMACHE'},
#   {'CodigoEmpresa': '7439', 'NombreEmpresa': 'Hospital de Litueche'},
#   {'CodigoEmpresa': '7447', 'NombreEmpresa': 'Hospital de Lolol'},
#   {'CodigoEmpresa': '7370', 'NombreEmpresa': 'HOSPITAL DE MEJILLONES'},
#   {'CodigoEmpresa': '7458', 'NombreEmpresa': 'Hospital de Melipilla'},
#   {'CodigoEmpresa': '7343', 'NombreEmpresa': 'HOSPITAL DE PETORCA'},
#   {'CodigoEmpresa': '7485', 'NombreEmpresa': 'HOSPITAL DE QUILPUE'},
#   {'CodigoEmpresa': '7460',
#    'NombreEmpresa': 'HOSPITAL DE URGENCIA ASISTENCIA PUBLICA DR ALEJANDRO DEL RIO'},
#   {'CodigoEmpresa': '1238663',
#    'NombreEmpresa': 'HOSPITAL DEL PERPETUO SOCORRO DE QUILACAHUIN'},
#   {'CodigoEmpresa': '7046',
#    'NombreEmpresa': 'HOSPITAL DOCTOR HERNAN HENRIQUEZ ARAVENA'},
#   {'CodigoEmpresa': '6936',
#    'NombreEmpresa': 'HOSPITAL DR GUSTAVO FRICKE DE VINA DEL MAR'},
#   {'CodigoEmpresa': '7344',
#    'NombreEmpresa': 'HOSPITAL DR MARIO SANCHEZ VERGARA LA CALERA'},
#   {'CodigoEmpresa': '7386',
#    'NombreEmpresa': 'Hospital Dr. Marcos Chamorro Iglesias'},
#   {'CodigoEmpresa': '1238659',
#    'NombreEmpresa': 'HOSPITAL FUTA SRÜKA LAWENCHE KUNKO MAPU MO'},
#   {'CodigoEmpresa': '7290', 'NombreEmpresa': 'Hospital Galvarino'},
#   {'CodigoEmpresa': '7490',
#    'NombreEmpresa': 'HOSPITAL GERIATRICO LA PAZ DE LA TARDE'},
#   {'CodigoEmpresa': '7324',
#    'NombreEmpresa': 'HOSPITAL GUILLERMO GRANT BENAVENTE DE CO'},
#   {'CodigoEmpresa': '7401',
#    'NombreEmpresa': 'HOSPITAL INTERCULTURAL KALLVU LLANKA.-'},
#   {'CodigoEmpresa': '1076658',
#    'NombreEmpresa': 'HOSPITAL METROPOLITANO DE SANTIAGO'},
#   {'CodigoEmpresa': '7130',
#    'NombreEmpresa': 'HOSPITAL ORIENTE DR LUIS TISNE BROUSSE'},
#   {'CodigoEmpresa': '7331', 'NombreEmpresa': 'HOSPITAL PADRE ALBERTO HURTADO'},
#   {'CodigoEmpresa': '102393', 'NombreEmpresa': 'HOSPITAL PANGUIPULLI'},
#   {'CodigoEmpresa': '7412',
#    'NombreEmpresa': 'HOSPITAL PROVINCIAL   DEL HUASCO MSR FERNANDO ARIZTIA RUIZ'},
#   {'CodigoEmpresa': '1216633',
#    'NombreEmpresa': 'HOSPITAL PSIQUIATRICO DR. PHILIPPE PINEL PUTAENDO'},
#   {'CodigoEmpresa': '7427', 'NombreEmpresa': 'Hospital Psiquiátrico El Peral'},
#   {'CodigoEmpresa': '127018',
#    'NombreEmpresa': 'HOSPITAL PUERTO MONTT SERVICIO DE SALUD DEL RELONCAVI'},
#   {'CodigoEmpresa': '7487',
#    'NombreEmpresa': 'HOSPITAL SAN AGUSTIN DE LA LIGUA'},
#   {'CodigoEmpresa': '7477',
#    'NombreEmpresa': 'Hospital Sanatorio San José de Maipo'},
#   {'CodigoEmpresa': '7318', 'NombreEmpresa': 'Hospital Santa Juana'},
#   {'CodigoEmpresa': '7049', 'NombreEmpresa': 'HOSPITAL VILCUN'},
#   {'CodigoEmpresa': '7132', 'NombreEmpresa': 'Hospital Villarrica'},
#   {'CodigoEmpresa': '7294', 'NombreEmpresa': 'I MUNICIPALIDAD DE ALGARROBO'},
#   {'CodigoEmpresa': '111124', 'NombreEmpresa': 'I MUNICIPALIDAD DE ALHUE'},
#   {'CodigoEmpresa': '98452', 'NombreEmpresa': 'I MUNICIPALIDAD DE ANCUD'},
#   {'CodigoEmpresa': '119639', 'NombreEmpresa': 'I MUNICIPALIDAD DE ANDACOLLO'},
#   {'CodigoEmpresa': '100156', 'NombreEmpresa': 'I MUNICIPALIDAD DE ANGOL'},
#   {'CodigoEmpresa': '87653',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE ANTOFAGASTA'},
#   {'CodigoEmpresa': '119484', 'NombreEmpresa': 'I MUNICIPALIDAD DE ANTUCO'},
#   {'CodigoEmpresa': '7050', 'NombreEmpresa': 'I MUNICIPALIDAD DE ARAUCO'},
#   {'CodigoEmpresa': '86624', 'NombreEmpresa': 'I MUNICIPALIDAD DE ARICA'},
#   {'CodigoEmpresa': '100049', 'NombreEmpresa': 'I MUNICIPALIDAD DE AYSEN'},
#   {'CodigoEmpresa': '100090', 'NombreEmpresa': 'I MUNICIPALIDAD DE BUIN'},
#   {'CodigoEmpresa': '118069', 'NombreEmpresa': 'I MUNICIPALIDAD DE BULNES'},
#   {'CodigoEmpresa': '115459', 'NombreEmpresa': 'I MUNICIPALIDAD DE CABILDO'},
#   {'CodigoEmpresa': '120186', 'NombreEmpresa': 'I MUNICIPALIDAD DE CABRERO'},
#   {'CodigoEmpresa': '86917', 'NombreEmpresa': 'I MUNICIPALIDAD DE CALAMA'},
#   {'CodigoEmpresa': '115011', 'NombreEmpresa': 'I MUNICIPALIDAD DE CALBUCO'},
#   {'CodigoEmpresa': '7364', 'NombreEmpresa': 'I MUNICIPALIDAD DE CALDERA'},
#   {'CodigoEmpresa': '116219',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE CALERA DE TANGO'},
#   {'CodigoEmpresa': '121539',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE CALLE LARGA'},
#   {'CodigoEmpresa': '84473', 'NombreEmpresa': 'I MUNICIPALIDAD DE CANELA'},
#   {'CodigoEmpresa': '119488', 'NombreEmpresa': 'I MUNICIPALIDAD DE CANETE'},
#   {'CodigoEmpresa': '115186', 'NombreEmpresa': 'I MUNICIPALIDAD DE CARAHUE'},
#   {'CodigoEmpresa': '99569', 'NombreEmpresa': 'I MUNICIPALIDAD DE CARTAGENA'},
#   {'CodigoEmpresa': '113614',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE CASABLANCA'},
#   {'CodigoEmpresa': '100127', 'NombreEmpresa': 'I MUNICIPALIDAD DE CASTRO'},
#   {'CodigoEmpresa': '129737', 'NombreEmpresa': 'I MUNICIPALIDAD DE CATEMU'},
#   {'CodigoEmpresa': '7351', 'NombreEmpresa': 'I MUNICIPALIDAD DE CAUQUENES'},
#   {'CodigoEmpresa': '7241', 'NombreEmpresa': 'I MUNICIPALIDAD DE CERRILLOS'},
#   {'CodigoEmpresa': '114392', 'NombreEmpresa': 'I MUNICIPALIDAD DE CHAITEN'},
#   {'CodigoEmpresa': '109196', 'NombreEmpresa': 'I MUNICIPALIDAD DE CHANARAL'},
#   {'CodigoEmpresa': '7501', 'NombreEmpresa': 'I MUNICIPALIDAD DE CHANCO'},
#   {'CodigoEmpresa': '92414', 'NombreEmpresa': 'I MUNICIPALIDAD DE CHEPICA'},
#   {'CodigoEmpresa': '100523',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE CHIGUAYANTE'},
#   {'CodigoEmpresa': '154782',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE CHILE CHICO'},
#   {'CodigoEmpresa': '88254', 'NombreEmpresa': 'I MUNICIPALIDAD DE CHILLAN'},
#   {'CodigoEmpresa': '116404',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE CHIMBARONGO'},
#   {'CodigoEmpresa': '115168', 'NombreEmpresa': 'I MUNICIPALIDAD DE CHONCHI'},
#   {'CodigoEmpresa': '116747', 'NombreEmpresa': 'I MUNICIPALIDAD DE CISNES'},
#   {'CodigoEmpresa': '114925',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE COBQUECURA'},
#   {'CodigoEmpresa': '116942', 'NombreEmpresa': 'I MUNICIPALIDAD DE COCHRANE'},
#   {'CodigoEmpresa': '165106', 'NombreEmpresa': 'I MUNICIPALIDAD DE CODEGUA'},
#   {'CodigoEmpresa': '116742', 'NombreEmpresa': 'I MUNICIPALIDAD DE COELEMU'},
#   {'CodigoEmpresa': '7146', 'NombreEmpresa': 'I MUNICIPALIDAD DE COIHUECO'},
#   {'CodigoEmpresa': '113254', 'NombreEmpresa': 'I MUNICIPALIDAD DE COINCO'},
#   {'CodigoEmpresa': '1053458', 'NombreEmpresa': 'I MUNICIPALIDAD DE COLCHANE'},
#   {'CodigoEmpresa': '99322', 'NombreEmpresa': 'I MUNICIPALIDAD DE COLINA'},
#   {'CodigoEmpresa': '113853',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE COLLIPULLI'},
#   {'CodigoEmpresa': '119266', 'NombreEmpresa': 'I MUNICIPALIDAD DE COLTAUCO'},
#   {'CodigoEmpresa': '87382', 'NombreEmpresa': 'I MUNICIPALIDAD DE CONCEPCION'},
#   {'CodigoEmpresa': '84958', 'NombreEmpresa': 'I MUNICIPALIDAD DE CONCHALI'},
#   {'CodigoEmpresa': '94458', 'NombreEmpresa': 'I MUNICIPALIDAD DE CONCON'},
#   {'CodigoEmpresa': '102316',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE CONSTITUCION'},
#   {'CodigoEmpresa': '86872', 'NombreEmpresa': 'I MUNICIPALIDAD DE COPIAPO'},
#   {'CodigoEmpresa': '87901', 'NombreEmpresa': 'I MUNICIPALIDAD DE COQUIMBO'},
#   {'CodigoEmpresa': '100448', 'NombreEmpresa': 'I MUNICIPALIDAD DE CORONEL'},
#   {'CodigoEmpresa': '7071', 'NombreEmpresa': 'I MUNICIPALIDAD DE COYHAIQUE'},
#   {'CodigoEmpresa': '129738', 'NombreEmpresa': 'I MUNICIPALIDAD DE CUNCO'},
#   {'CodigoEmpresa': '121613',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE CURACAUTIN'},
#   {'CodigoEmpresa': '125602', 'NombreEmpresa': 'I MUNICIPALIDAD DE CURACAVI'},
#   {'CodigoEmpresa': '114393',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE CURACO DE VELEZ'},
#   {'CodigoEmpresa': '127036',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE CURANILAHUE'},
#   {'CodigoEmpresa': '87838', 'NombreEmpresa': 'I MUNICIPALIDAD DE CURICO'},
#   {'CodigoEmpresa': '115165', 'NombreEmpresa': 'I MUNICIPALIDAD DE DALCAHUE'},
#   {'CodigoEmpresa': '123788', 'NombreEmpresa': 'I MUNICIPALIDAD DE DONIHUE'},
#   {'CodigoEmpresa': '116741', 'NombreEmpresa': 'I MUNICIPALIDAD DE EL MONTE'},
#   {'CodigoEmpresa': '116298', 'NombreEmpresa': 'I MUNICIPALIDAD DE EL QUISCO'},
#   {'CodigoEmpresa': '7066', 'NombreEmpresa': 'I MUNICIPALIDAD DE EL TABO'},
#   {'CodigoEmpresa': '116944', 'NombreEmpresa': 'I MUNICIPALIDAD DE EMPEDRADO'},
#   {'CodigoEmpresa': '132741', 'NombreEmpresa': 'I MUNICIPALIDAD DE ERCILLA'},
#   {'CodigoEmpresa': '115285', 'NombreEmpresa': 'I MUNICIPALIDAD DE FLORIDA'},
#   {'CodigoEmpresa': '118089', 'NombreEmpresa': 'I MUNICIPALIDAD DE FREIRE'},
#   {'CodigoEmpresa': '135567', 'NombreEmpresa': 'I MUNICIPALIDAD DE FREIRINA'},
#   {'CodigoEmpresa': '119651', 'NombreEmpresa': 'I MUNICIPALIDAD DE FRESIA'},
#   {'CodigoEmpresa': '84478', 'NombreEmpresa': 'I MUNICIPALIDAD DE FRUTILLAR'},
#   {'CodigoEmpresa': '118068', 'NombreEmpresa': 'I MUNICIPALIDAD DE FUTALEUFU'},
#   {'CodigoEmpresa': '106880', 'NombreEmpresa': 'I MUNICIPALIDAD DE FUTRONO'},
#   {'CodigoEmpresa': '148507', 'NombreEmpresa': 'I MUNICIPALIDAD DE GRANEROS'},
#   {'CodigoEmpresa': '116733', 'NombreEmpresa': 'I MUNICIPALIDAD DE HIJUELAS'},
#   {'CodigoEmpresa': '106170', 'NombreEmpresa': 'I MUNICIPALIDAD DE HUALAIHUE'},
#   {'CodigoEmpresa': '118855', 'NombreEmpresa': 'I MUNICIPALIDAD DE HUALANE'},
#   {'CodigoEmpresa': '140867', 'NombreEmpresa': 'I MUNICIPALIDAD DE HUALQUI'},
#   {'CodigoEmpresa': '116406', 'NombreEmpresa': 'I MUNICIPALIDAD DE HUASCO'},
#   {'CodigoEmpresa': '115164', 'NombreEmpresa': 'I MUNICIPALIDAD DE ILLAPEL'},
#   {'CodigoEmpresa': '99105',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE INDEPENDENCIA'},
#   {'CodigoEmpresa': '87175', 'NombreEmpresa': 'I MUNICIPALIDAD DE IQUIQUE'},
#   {'CodigoEmpresa': '117181',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE ISLA DE MAIPO'},
#   {'CodigoEmpresa': '119852',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE ISLA DE PASCUA'},
#   {'CodigoEmpresa': '108932',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE JUAN FERNANDEZ'},
#   {'CodigoEmpresa': '115185', 'NombreEmpresa': 'I MUNICIPALIDAD DE LA CALERA'},
#   {'CodigoEmpresa': '100488',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE LA CISTERNA'},
#   {'CodigoEmpresa': '7496',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE LA COMUNA DE EL BOSQUE'},
#   {'CodigoEmpresa': '113255', 'NombreEmpresa': 'I MUNICIPALIDAD DE LA CRUZ'},
#   {'CodigoEmpresa': '165285',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE LA ESTRELLA'},
#   {'CodigoEmpresa': '86766', 'NombreEmpresa': 'I MUNICIPALIDAD DE LA FLORIDA'},
#   {'CodigoEmpresa': '112097', 'NombreEmpresa': 'I MUNICIPALIDAD DE LA GRANJA'},
#   {'CodigoEmpresa': '116410',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE LA HIGUERA'},
#   {'CodigoEmpresa': '100648', 'NombreEmpresa': 'I MUNICIPALIDAD DE LA LIGUA'},
#   {'CodigoEmpresa': '83825', 'NombreEmpresa': 'I MUNICIPALIDAD DE LA PINTANA'},
#   {'CodigoEmpresa': '7366', 'NombreEmpresa': 'I MUNICIPALIDAD DE LA REINA'},
#   {'CodigoEmpresa': '114725', 'NombreEmpresa': 'I MUNICIPALIDAD DE LA UNION'},
#   {'CodigoEmpresa': '113735',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE LAGO RANCO'},
#   {'CodigoEmpresa': '123529',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE LAGO VERDE'},
#   {'CodigoEmpresa': '119999',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE LAGUNA BLANCA'},
#   {'CodigoEmpresa': '116405', 'NombreEmpresa': 'I MUNICIPALIDAD DE LAJA'},
#   {'CodigoEmpresa': '118067', 'NombreEmpresa': 'I MUNICIPALIDAD DE LAMPA'},
#   {'CodigoEmpresa': '106876', 'NombreEmpresa': 'I MUNICIPALIDAD DE LANCO'},
#   {'CodigoEmpresa': '116296',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE LAS CABRAS'},
#   {'CodigoEmpresa': '86571', 'NombreEmpresa': 'I MUNICIPALIDAD DE LAS CONDES'},
#   {'CodigoEmpresa': '165107',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE LAS GUAITECAS'},
#   {'CodigoEmpresa': '124577', 'NombreEmpresa': 'I MUNICIPALIDAD DE LAUTARO'},
#   {'CodigoEmpresa': '118096', 'NombreEmpresa': 'I MUNICIPALIDAD DE LEBU'},
#   {'CodigoEmpresa': '114398', 'NombreEmpresa': 'I MUNICIPALIDAD DE LICANTEN'},
#   {'CodigoEmpresa': '7492', 'NombreEmpresa': 'I MUNICIPALIDAD DE LIMACHE'},
#   {'CodigoEmpresa': '86545', 'NombreEmpresa': 'I MUNICIPALIDAD DE LINARES'},
#   {'CodigoEmpresa': '7365', 'NombreEmpresa': 'I MUNICIPALIDAD DE LITUECHE'},
#   {'CodigoEmpresa': '7064', 'NombreEmpresa': 'I MUNICIPALIDAD DE LLANQUIHUE'},
#   {'CodigoEmpresa': '118072', 'NombreEmpresa': 'I MUNICIPALIDAD DE LLAY LLAY'},
#   {'CodigoEmpresa': '86518', 'NombreEmpresa': 'I MUNICIPALIDAD DE LO ESPEJO'},
#   {'CodigoEmpresa': '87373', 'NombreEmpresa': 'I MUNICIPALIDAD DE LO PRADO'},
#   {'CodigoEmpresa': '113258', 'NombreEmpresa': 'I MUNICIPALIDAD DE LOLOL'},
#   {'CodigoEmpresa': '113851', 'NombreEmpresa': 'I MUNICIPALIDAD DE LONCOCHE'},
#   {'CodigoEmpresa': '120788', 'NombreEmpresa': 'I MUNICIPALIDAD DE LONGAVI'},
#   {'CodigoEmpresa': '119994', 'NombreEmpresa': 'I MUNICIPALIDAD DE LONQUIMAY'},
#   {'CodigoEmpresa': '118620',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE LOS ALAMOS DEPTO COMUNAL'},
#   {'CodigoEmpresa': '87187',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE LOS ANGELES'},
#   {'CodigoEmpresa': '7159', 'NombreEmpresa': 'I MUNICIPALIDAD DE LOS LAGOS'},
#   {'CodigoEmpresa': '7304', 'NombreEmpresa': 'I MUNICIPALIDAD DE LOS MUERMOS'},
#   {'CodigoEmpresa': '116408',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE LOS SAUCES'},
#   {'CodigoEmpresa': '116401', 'NombreEmpresa': 'I MUNICIPALIDAD DE LOS VILOS'},
#   {'CodigoEmpresa': '113259', 'NombreEmpresa': 'I MUNICIPALIDAD DE LOTA'},
#   {'CodigoEmpresa': '115464', 'NombreEmpresa': 'I MUNICIPALIDAD DE MAFIL'},
#   {'CodigoEmpresa': '93619', 'NombreEmpresa': 'I MUNICIPALIDAD DE MAIPU'},
#   {'CodigoEmpresa': '115609', 'NombreEmpresa': 'I MUNICIPALIDAD DE MALLOA'},
#   {'CodigoEmpresa': '115304', 'NombreEmpresa': 'I MUNICIPALIDAD DE MARCHIGUE'},
#   {'CodigoEmpresa': '113738',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE MARIA ELENA'},
#   {'CodigoEmpresa': '120798',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE MARIA PINTO'},
#   {'CodigoEmpresa': '120001', 'NombreEmpresa': 'I MUNICIPALIDAD DE MARIQUINA'},
#   {'CodigoEmpresa': '118070', 'NombreEmpresa': 'I MUNICIPALIDAD DE MAULE'},
#   {'CodigoEmpresa': '120791', 'NombreEmpresa': 'I MUNICIPALIDAD DE MAULLIN'},
#   {'CodigoEmpresa': '117581',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE MEJILLONES'},
#   {'CodigoEmpresa': '112924',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE MONTEPATRIA'},
#   {'CodigoEmpresa': '99101', 'NombreEmpresa': 'I MUNICIPALIDAD DE MOSTAZAL'},
#   {'CodigoEmpresa': '115311', 'NombreEmpresa': 'I MUNICIPALIDAD DE MULCHEN'},
#   {'CodigoEmpresa': '135561',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE NACIMIENTO'},
#   {'CodigoEmpresa': '116750', 'NombreEmpresa': 'I MUNICIPALIDAD DE NANCAGUA'},
#   {'CodigoEmpresa': '118625', 'NombreEmpresa': 'I MUNICIPALIDAD DE NAVIDAD'},
#   {'CodigoEmpresa': '142508', 'NombreEmpresa': 'I MUNICIPALIDAD DE NEGRETE'},
#   {'CodigoEmpresa': '7051', 'NombreEmpresa': 'I MUNICIPALIDAD DE NINHUE'},
#   {'CodigoEmpresa': '115468', 'NombreEmpresa': 'I MUNICIPALIDAD DE NOGALES'},
#   {'CodigoEmpresa': '114924',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE NUEVA IMPERIAL'},
#   {'CodigoEmpresa': '86764', 'NombreEmpresa': 'I MUNICIPALIDAD DE NUNOA'},
#   {'CodigoEmpresa': '115463', 'NombreEmpresa': 'I MUNICIPALIDAD DE O HIGGINS'},
#   {'CodigoEmpresa': '119273', 'NombreEmpresa': 'I MUNICIPALIDAD DE OLIVAR'},
#   {'CodigoEmpresa': '119996', 'NombreEmpresa': 'I MUNICIPALIDAD DE OLLAGUE'},
#   {'CodigoEmpresa': '114724', 'NombreEmpresa': 'I MUNICIPALIDAD DE OLMUE'},
#   {'CodigoEmpresa': '84959', 'NombreEmpresa': 'I MUNICIPALIDAD DE OSORNO'},
#   {'CodigoEmpresa': '117406',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE PADRE HURTADO'},
#   {'CodigoEmpresa': '90886',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE PADRE LAS CASAS'},
#   {'CodigoEmpresa': '116744', 'NombreEmpresa': 'I MUNICIPALIDAD DE PAILLACO'},
#   {'CodigoEmpresa': '100728', 'NombreEmpresa': 'I MUNICIPALIDAD DE PAINE'},
#   {'CodigoEmpresa': '110393', 'NombreEmpresa': 'I MUNICIPALIDAD DE PALENA'},
#   {'CodigoEmpresa': '123526', 'NombreEmpresa': 'I MUNICIPALIDAD DE PALMILLA'},
#   {'CodigoEmpresa': '115284',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE PANGUIPULLI'},
#   {'CodigoEmpresa': '113618', 'NombreEmpresa': 'I MUNICIPALIDAD DE PANQUEHUE'},
#   {'CodigoEmpresa': '115302', 'NombreEmpresa': 'I MUNICIPALIDAD DE PAPUDO'},
#   {'CodigoEmpresa': '118971', 'NombreEmpresa': 'I MUNICIPALIDAD DE PAREDONES'},
#   {'CodigoEmpresa': '94459', 'NombreEmpresa': 'I MUNICIPALIDAD DE PARRAL'},
#   {'CodigoEmpresa': '116729', 'NombreEmpresa': 'I MUNICIPALIDAD DE PELARCO'},
#   {'CodigoEmpresa': '113978', 'NombreEmpresa': 'I MUNICIPALIDAD DE PELLUHUE'},
#   {'CodigoEmpresa': '117587', 'NombreEmpresa': 'I MUNICIPALIDAD DE PEMUCO'},
#   {'CodigoEmpresa': '87172', 'NombreEmpresa': 'I MUNICIPALIDAD DE PENALOLEN'},
#   {'CodigoEmpresa': '115166', 'NombreEmpresa': 'I MUNICIPALIDAD DE PENCAHUE'},
#   {'CodigoEmpresa': '142575', 'NombreEmpresa': 'I MUNICIPALIDAD DE PENCO'},
#   {'CodigoEmpresa': '118619', 'NombreEmpresa': 'I MUNICIPALIDAD DE PERALILLO'},
#   {'CodigoEmpresa': '133899', 'NombreEmpresa': 'I MUNICIPALIDAD DE PERQUENCO'},
#   {'CodigoEmpresa': '116223', 'NombreEmpresa': 'I MUNICIPALIDAD DE PETORCA'},
#   {'CodigoEmpresa': '118861', 'NombreEmpresa': 'I MUNICIPALIDAD DE PEUMO'},
#   {'CodigoEmpresa': '118077', 'NombreEmpresa': 'I MUNICIPALIDAD DE PICA'},
#   {'CodigoEmpresa': '118621',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE PICHIDEGUA'},
#   {'CodigoEmpresa': '118071', 'NombreEmpresa': 'I MUNICIPALIDAD DE PINTO'},
#   {'CodigoEmpresa': '100072', 'NombreEmpresa': 'I MUNICIPALIDAD DE PIRQUE'},
#   {'CodigoEmpresa': '116411',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE PITRUFQUEN'},
#   {'CodigoEmpresa': '118087', 'NombreEmpresa': 'I MUNICIPALIDAD DE PLACILLA'},
#   {'CodigoEmpresa': '115299',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE PORTEZUELO'},
#   {'CodigoEmpresa': '117585', 'NombreEmpresa': 'I MUNICIPALIDAD DE PRIMAVERA'},
#   {'CodigoEmpresa': '88102',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE PROVIDENCIA'},
#   {'CodigoEmpresa': '119270',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE PUCHUNCAVI'},
#   {'CodigoEmpresa': '86943', 'NombreEmpresa': 'I MUNICIPALIDAD DE PUCON'},
#   {'CodigoEmpresa': '87388',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE PUENTE ALTO'},
#   {'CodigoEmpresa': '86507',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE PUERTO MONTT'},
#   {'CodigoEmpresa': '102868',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE PUERTO VARAS'},
#   {'CodigoEmpresa': '116402', 'NombreEmpresa': 'I MUNICIPALIDAD DE PUMANQUE'},
#   {'CodigoEmpresa': '117588', 'NombreEmpresa': 'I MUNICIPALIDAD DE PUNITAQUI'},
#   {'CodigoEmpresa': '86580',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE PUNTA ARENAS'},
#   {'CodigoEmpresa': '116403', 'NombreEmpresa': 'I MUNICIPALIDAD DE PUQUELDON'},
#   {'CodigoEmpresa': '116945', 'NombreEmpresa': 'I MUNICIPALIDAD DE PUREN'},
#   {'CodigoEmpresa': '114916', 'NombreEmpresa': 'I MUNICIPALIDAD DE PURRANQUE'},
#   {'CodigoEmpresa': '98280', 'NombreEmpresa': 'I MUNICIPALIDAD DE PUTAENDO'},
#   {'CodigoEmpresa': '105334', 'NombreEmpresa': 'I MUNICIPALIDAD DE PUYEHUE'},
#   {'CodigoEmpresa': '112919', 'NombreEmpresa': 'I MUNICIPALIDAD DE QUEILEN'},
#   {'CodigoEmpresa': '125066', 'NombreEmpresa': 'I MUNICIPALIDAD DE QUEMCHI'},
#   {'CodigoEmpresa': '116940', 'NombreEmpresa': 'I MUNICIPALIDAD DE QUILACO'},
#   {'CodigoEmpresa': '88313', 'NombreEmpresa': 'I MUNICIPALIDAD DE QUILICURA'},
#   {'CodigoEmpresa': '115979', 'NombreEmpresa': 'I MUNICIPALIDAD DE QUILLECO'},
#   {'CodigoEmpresa': '88203', 'NombreEmpresa': 'I MUNICIPALIDAD DE QUILLOTA'},
#   {'CodigoEmpresa': '116731', 'NombreEmpresa': 'I MUNICIPALIDAD DE QUINCHAO'},
#   {'CodigoEmpresa': '115010',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE QUINTA DE TILCOCO'},
#   {'CodigoEmpresa': '138454', 'NombreEmpresa': 'I MUNICIPALIDAD DE QUINTERO'},
#   {'CodigoEmpresa': '87167', 'NombreEmpresa': 'I MUNICIPALIDAD DE RANCAGUA'},
#   {'CodigoEmpresa': '117589', 'NombreEmpresa': 'I MUNICIPALIDAD DE RAUCO'},
#   {'CodigoEmpresa': '7325', 'NombreEmpresa': 'I MUNICIPALIDAD DE RECOLETA'},
#   {'CodigoEmpresa': '118073', 'NombreEmpresa': 'I MUNICIPALIDAD DE RENAICO'},
#   {'CodigoEmpresa': '87185', 'NombreEmpresa': 'I MUNICIPALIDAD DE RENCA'},
#   {'CodigoEmpresa': '100555', 'NombreEmpresa': 'I MUNICIPALIDAD DE RENGO'},
#   {'CodigoEmpresa': '116215', 'NombreEmpresa': 'I MUNICIPALIDAD DE REQUINOA'},
#   {'CodigoEmpresa': '114918', 'NombreEmpresa': 'I MUNICIPALIDAD DE RINCONADA'},
#   {'CodigoEmpresa': '117580', 'NombreEmpresa': 'I MUNICIPALIDAD DE RIO BUENO'},
#   {'CodigoEmpresa': '89591', 'NombreEmpresa': 'I MUNICIPALIDAD DE RIO CLARO'},
#   {'CodigoEmpresa': '114075',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE RIO HURTADO'},
#   {'CodigoEmpresa': '7367', 'NombreEmpresa': 'I MUNICIPALIDAD DE RIO NEGRO'},
#   {'CodigoEmpresa': '115313', 'NombreEmpresa': 'I MUNICIPALIDAD DE SAAVEDRA'},
#   {'CodigoEmpresa': '116295', 'NombreEmpresa': 'I MUNICIPALIDAD DE SALAMANCA'},
#   {'CodigoEmpresa': '100318',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN ANTONIO'},
#   {'CodigoEmpresa': '86548',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN BERNARDO'},
#   {'CodigoEmpresa': '93774',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN CLEMENTE'},
#   {'CodigoEmpresa': '116226',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN ESTEBAN'},
#   {'CodigoEmpresa': '128889',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN FABIAN'},
#   {'CodigoEmpresa': '100158',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN FELIPE'},
#   {'CodigoEmpresa': '7482',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN FERNANDO'},
#   {'CodigoEmpresa': '116409',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN IGNACIO'},
#   {'CodigoEmpresa': '86407', 'NombreEmpresa': 'I MUNICIPALIDAD DE SAN JAVIER'},
#   {'CodigoEmpresa': '115457',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN JOSE DE MAIPO'},
#   {'CodigoEmpresa': '7498', 'NombreEmpresa': 'I MUNICIPALIDAD DE SAN MIGUEL'},
#   {'CodigoEmpresa': '7158', 'NombreEmpresa': 'I MUNICIPALIDAD DE SAN NICOLAS'},
#   {'CodigoEmpresa': '111960', 'NombreEmpresa': 'I MUNICIPALIDAD DE SAN PABLO'},
#   {'CodigoEmpresa': '142855', 'NombreEmpresa': 'I MUNICIPALIDAD DE SAN PEDRO'},
#   {'CodigoEmpresa': '113428',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN PEDRO DE ATACAMA'},
#   {'CodigoEmpresa': '100704',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN PEDRO DE LA PAZ'},
#   {'CodigoEmpresa': '113913',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN RAFAEL'},
#   {'CodigoEmpresa': '7355', 'NombreEmpresa': 'I MUNICIPALIDAD DE SAN RAMON'},
#   {'CodigoEmpresa': '136421',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN ROSENDO'},
#   {'CodigoEmpresa': '135559',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SAN VICENTE'},
#   {'CodigoEmpresa': '118860',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SANTA BARBARA'},
#   {'CodigoEmpresa': '117584',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SANTA CRUZ'},
#   {'CodigoEmpresa': '118623',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SANTA JUANA'},
#   {'CodigoEmpresa': '117210',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SANTA MARIA'},
#   {'CodigoEmpresa': '86568', 'NombreEmpresa': 'I MUNICIPALIDAD DE SANTIAGO'},
#   {'CodigoEmpresa': '113981',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SANTO DOMINGO'},
#   {'CodigoEmpresa': '117579',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE SIERRA GORDA'},
#   {'CodigoEmpresa': '99765', 'NombreEmpresa': 'I MUNICIPALIDAD DE TALAGANTE'},
#   {'CodigoEmpresa': '84480', 'NombreEmpresa': 'I MUNICIPALIDAD DE TALCA'},
#   {'CodigoEmpresa': '86586', 'NombreEmpresa': 'I MUNICIPALIDAD DE TALCAHUANO'},
#   {'CodigoEmpresa': '118079', 'NombreEmpresa': 'I MUNICIPALIDAD DE TALTAL'},
#   {'CodigoEmpresa': '7321', 'NombreEmpresa': 'I MUNICIPALIDAD DE TEMUCO'},
#   {'CodigoEmpresa': '116299', 'NombreEmpresa': 'I MUNICIPALIDAD DE TENO'},
#   {'CodigoEmpresa': '7360',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE TIERRA AMARILLA'},
#   {'CodigoEmpresa': '116218', 'NombreEmpresa': 'I MUNICIPALIDAD DE TIL TIL'},
#   {'CodigoEmpresa': '183037', 'NombreEmpresa': 'I MUNICIPALIDAD DE TIRUA'},
#   {'CodigoEmpresa': '115167', 'NombreEmpresa': 'I MUNICIPALIDAD DE TOCOPILLA'},
#   {'CodigoEmpresa': '98443', 'NombreEmpresa': 'I MUNICIPALIDAD DE TOME'},
#   {'CodigoEmpresa': '145365', 'NombreEmpresa': 'I MUNICIPALIDAD DE TREHUACO'},
#   {'CodigoEmpresa': '114395', 'NombreEmpresa': 'I MUNICIPALIDAD DE TUCAPEL'},
#   {'CodigoEmpresa': '86491', 'NombreEmpresa': 'I MUNICIPALIDAD DE VALLENAR'},
#   {'CodigoEmpresa': '87402', 'NombreEmpresa': 'I MUNICIPALIDAD DE VALPARAISO'},
#   {'CodigoEmpresa': '114914', 'NombreEmpresa': 'I MUNICIPALIDAD DE VICHUQUEN'},
#   {'CodigoEmpresa': '116399', 'NombreEmpresa': 'I MUNICIPALIDAD DE VICTORIA'},
#   {'CodigoEmpresa': '115303', 'NombreEmpresa': 'I MUNICIPALIDAD DE VICUNA'},
#   {'CodigoEmpresa': '115009', 'NombreEmpresa': 'I MUNICIPALIDAD DE VILCUN'},
#   {'CodigoEmpresa': '7363',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE VILLA ALEGRE'},
#   {'CodigoEmpresa': '7233',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE VILLA ALEMANA'},
#   {'CodigoEmpresa': '118084',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE VILLARRICA'},
#   {'CodigoEmpresa': '87399',
#    'NombreEmpresa': 'I MUNICIPALIDAD DE VINA DEL MAR'},
#   {'CodigoEmpresa': '98462', 'NombreEmpresa': 'I MUNICIPALIDAD DE VITACURA'},
#   {'CodigoEmpresa': '120004', 'NombreEmpresa': 'I MUNICIPALIDAD DE YUMBEL'},
#   {'CodigoEmpresa': '115294', 'NombreEmpresa': 'I MUNICIPALIDAD DE YUNGAY'},
#   {'CodigoEmpresa': '132199', 'NombreEmpresa': 'I MUNICIPALIDAD DE ZAPALLAR'},
#   {'CodigoEmpresa': '87824',
#    'NombreEmpresa': 'I MUNICIPALIDAD ESTACION CENTRAL'},
#   {'CodigoEmpresa': '100155', 'NombreEmpresa': 'I MUNICIPALIDAD LO BARNECHEA'},
#   {'CodigoEmpresa': '118075', 'NombreEmpresa': 'I MUNICIPALIDAD PAIHUANO'},
#   {'CodigoEmpresa': '87104',
#    'NombreEmpresa': 'I MUNICIPALIDAD PEDRO AGUIRRE CERDA'},
#   {'CodigoEmpresa': '104899', 'NombreEmpresa': 'I MUNICIPALIDAD PUERTO OCTAY'},
#   {'CodigoEmpresa': '120002', 'NombreEmpresa': 'I MUNICIPALIDAD RIO IBANEZ'},
#   {'CodigoEmpresa': '7135', 'NombreEmpresa': 'I MUNICIPALIDAD SAN JOAQUIN'},
#   {'CodigoEmpresa': '84152', 'NombreEmpresa': 'I MUNICIPALIDAD VALDIVIA'},
#   {'CodigoEmpresa': '87633', 'NombreEmpresa': 'I. MUNICIPALIDAD DE QUILPUE'},
#   {'CodigoEmpresa': '86664',
#    'NombreEmpresa': 'I.MUNICIPALIDAD DE CERRO NAVIA'},
# ...
#   {'CodigoEmpresa': '7421',
#    'NombreEmpresa': 'SERVICIO DE SALUD HOSPITAL COINCO'},
#   {'CodigoEmpresa': '7441',
#    'NombreEmpresa': 'SERVICIO DE SALUD HOSPITAL DE CHIMBARONGO'},
#   {'CodigoEmpresa': '7449',
#    'NombreEmpresa': 'SERVICIO DE SALUD HOSPITAL DE GRANEROS'},
#   {'CodigoEmpresa': '7442',
#    'NombreEmpresa': 'SERVICIO DE SALUD HOSPITAL DE MARCHIGUE'},
#   {'CodigoEmpresa': '7445',
#    'NombreEmpresa': 'SERVICIO DE SALUD HOSPITAL DE NANCAGUA'},
#   {'CodigoEmpresa': '7444',
#    'NombreEmpresa': 'SERVICIO DE SALUD HOSPITAL DE PEUMO'},
#   {'CodigoEmpresa': '7435',
#    'NombreEmpresa': 'SERVICIO DE SALUD HOSPITAL DE PICHIDEGUA'},
#   {'CodigoEmpresa': '7436',
#    'NombreEmpresa': 'SERVICIO DE SALUD HOSPITAL DE PICHILEMU'},
#   {'CodigoEmpresa': '7440',
#    'NombreEmpresa': 'SERVICIO DE SALUD HOSPITAL DE RENGO'},
#   {'CodigoEmpresa': '7448',
#    'NombreEmpresa': 'SERVICIO DE SALUD HOSPITAL DE SAN FERNANDO'},
#   {'CodigoEmpresa': '7443',
#    'NombreEmpresa': 'SERVICIO DE SALUD HOSPITAL DE SAN VICENTE DE TAGUA TAGUA'},
#   {'CodigoEmpresa': '7314',
#    'NombreEmpresa': 'SERVICIO DE SALUD HOSPITAL DE SANTA CRUZ'},
#   {'CodigoEmpresa': '7453', 'NombreEmpresa': 'SERVICIO DE SALUD IQUIQUE'},
#   {'CodigoEmpresa': '7054',
#    'NombreEmpresa': 'SERVICIO DE SALUD LIBERTADOR BDO OHIGGINS'},
#   {'CodigoEmpresa': '7106', 'NombreEmpresa': 'SERVICIO DE SALUD LOS RIOS'},
#   {'CodigoEmpresa': '7382', 'NombreEmpresa': 'SERVICIO DE SALUD MAGALLANES'},
#   {'CodigoEmpresa': '7310',
#    'NombreEmpresa': 'SERVICIO DE SALUD MAGALLANES HOSPITAL DE PTO NATALES'},
#   {'CodigoEmpresa': '7466',
#    'NombreEmpresa': 'SERVICIO DE SALUD METROPOLI CENTRAL DIRECCION DE ATENCION PRIMARIA'},
#   {'CodigoEmpresa': '7406',
#    'NombreEmpresa': 'SERVICIO DE SALUD METROPOLITANA NORTE HOSPITAL SAN JOSE'},
#   {'CodigoEmpresa': '7088',
#    'NombreEmpresa': 'SERVICIO DE SALUD METROPOLITANO CENTRAL'},
#   {'CodigoEmpresa': '7188',
#    'NombreEmpresa': 'Servicio de Salud Metropolitano del Ambiente'},
#   {'CodigoEmpresa': '6963',
#    'NombreEmpresa': 'SERVICIO DE SALUD METROPOLITANO NORTE'},
#   {'CodigoEmpresa': '7274',
#    'NombreEmpresa': 'SERVICIO DE SALUD METROPOLITANO NORTE HOSPITAL DE TIL TIL'},
#   {'CodigoEmpresa': '7455',
#    'NombreEmpresa': 'SERVICIO DE SALUD METROPOLITANO OCCIDENTE HOSPITAL DE CURACAVI'},
#   {'CodigoEmpresa': '7293',
#    'NombreEmpresa': 'SERVICIO DE SALUD METROPOLITANO SUR HOSP'},
#   {'CodigoEmpresa': '7203',
#    'NombreEmpresa': 'SERVICIO DE SALUD METROPOLITANO SUR ORIENTE'},
#   {'CodigoEmpresa': '7045',
#    'NombreEmpresa': 'SERVICIO DE SALUD NORTE HOSPITAL ROBERTO DEL RIO'},
#   {'CodigoEmpresa': '6932', 'NombreEmpresa': 'SERVICIO DE SALUD NUBLE'},
#   {'CodigoEmpresa': '7139',
#    'NombreEmpresa': 'SERVICIO DE SALUD NUBLE HOSPITAL DE EL C'},
#   {'CodigoEmpresa': '7303',
#    'NombreEmpresa': 'SERVICIO DE SALUD NUBLE HOSPITAL DE QUIRIHUE'},
#   {'CodigoEmpresa': '7469',
#    'NombreEmpresa': 'SERVICIO DE SALUD NUBLE HOSPITAL DE SAN CARLOS DR BENICIO ARZOLA MEDIN'},
#   {'CodigoEmpresa': '7053',
#    'NombreEmpresa': 'SERVICIO DE SALUD NUBLE HOSPITAL DE YUNG'},
#   {'CodigoEmpresa': '7316',
#    'NombreEmpresa': 'SERVICIO DE SALUD OCCIDENTE HOSPITAL SAN JUAN DE DIOS'},
#   {'CodigoEmpresa': '7456',
#    'NombreEmpresa': 'SERVICIO DE SALUD OCCIDENTE INSTITUTO TRAUMATOLOGICO DE SANTIAGO'},
#   {'CodigoEmpresa': '7428',
#    'NombreEmpresa': 'SERVICIO DE SALUD ORIENTE HOSPITAL DEL SALVADOR'},
#   {'CodigoEmpresa': '6918',
#    'NombreEmpresa': 'SERVICIO DE SALUD ORIENTE HOSPITAL LUIS CALVO MACKENNA'},
#   {'CodigoEmpresa': '7296', 'NombreEmpresa': 'SERVICIO DE SALUD OSORNO'},
#   {'CodigoEmpresa': '7327',
#    'NombreEmpresa': 'SERVICIO DE SALUD OSORNO HOSPITAL PURRANQUE'},
#   {'CodigoEmpresa': '7305',
#    'NombreEmpresa': 'SERVICIO DE SALUD SUR HOSPITAL EXEQUIEL'},
#   {'CodigoEmpresa': '7311',
#    'NombreEmpresa': 'SERVICIO DE SALUD SUR HOSPITAL LUCIO CORDOVA'},
#   {'CodigoEmpresa': '7405',
#    'NombreEmpresa': 'SERVICIO DE SALUD SUR HOSPITAL SAN LUIS'},
#   {'CodigoEmpresa': '7390',
#    'NombreEmpresa': 'SERVICIO DE SALUD SUR HOSPITAL SANATORIO EL PINO'},
#   {'CodigoEmpresa': '7006',
#    'NombreEmpresa': 'SERVICIO DE SALUD SUR UNIDAD HOSPITALARI'},
#   {'CodigoEmpresa': '7315',
#    'NombreEmpresa': 'SERVICIO DE SALUD TALCAHUANO HOSPITAL DE'},
#   {'CodigoEmpresa': '7410',
#    'NombreEmpresa': 'SERVICIO DE SALUD VALDIVIA HOSPITAL BASE'},
#   {'CodigoEmpresa': '7426',
#    'NombreEmpresa': 'SERVICIO DE SALUD VALDIVIA HOSPITAL DE C'},
#   {'CodigoEmpresa': '7425',
#    'NombreEmpresa': 'SERVICIO DE SALUD VALDIVIA HOSPITAL DE L'},
#   {'CodigoEmpresa': '7422',
#    'NombreEmpresa': 'SERVICIO DE SALUD VALDIVIA HOSPITAL DE P'},
#   {'CodigoEmpresa': '7423',
#    'NombreEmpresa': 'SERVICIO DE SALUD VALDIVIA HOSPITAL DE R'},
#   {'CodigoEmpresa': '7429',
#    'NombreEmpresa': 'SERVICIO DE SALUD VALDIVIA HOSPITAL LA U'},
#   {'CodigoEmpresa': '7424',
#    'NombreEmpresa': 'SERVICIO DE SALUD VALDIVIA HOSPITAL LANC'},
#   {'CodigoEmpresa': '7239',
#    'NombreEmpresa': 'SERVICIO DE SALUD VALPARAISO SAN ANTONIO'},
#   {'CodigoEmpresa': '7345',
#    'NombreEmpresa': 'SERVICIO DE SALUD VINA DEL MAR QUILLOTA'},
#   {'CodigoEmpresa': '7489',
#    'NombreEmpresa': 'SERVICIO DE SALUD VINA DEL MAR QUILLOTA'},
#   {'CodigoEmpresa': '6965',
#    'NombreEmpresa': 'SERVICIO DE VIVIENDA Y URBANIZACION AREA METROPOLITANA'},
#   {'CodigoEmpresa': '6923',
#    'NombreEmpresa': 'SERVICIO DE VIVIENDA Y URBANIZACION I REGION'},
#   {'CodigoEmpresa': '6974',
#    'NombreEmpresa': 'SERVICIO DE VIVIENDA Y URBANIZACION II REGION'},
#   {'CodigoEmpresa': '6975',
#    'NombreEmpresa': 'SERVICIO DE VIVIENDA Y URBANIZACION III REGION'},
#   {'CodigoEmpresa': '6972',
#    'NombreEmpresa': 'SERVICIO DE VIVIENDA Y URBANIZACION IV REGION'},
#   {'CodigoEmpresa': '6980',
#    'NombreEmpresa': 'SERVICIO DE VIVIENDA Y URBANIZACION IX REGION'},
#   {'CodigoEmpresa': '6979',
#    'NombreEmpresa': 'SERVICIO DE VIVIENDA Y URBANIZACION REGIÓN DEL BIO BIO'},
#   {'CodigoEmpresa': '6968',
#    'NombreEmpresa': 'SERVICIO DE VIVIENDA Y URBANIZACION V REGION'},
#   {'CodigoEmpresa': '6977',
#    'NombreEmpresa': 'SERVICIO DE VIVIENDA Y URBANIZACION VI REGION'},
#   {'CodigoEmpresa': '6978',
#    'NombreEmpresa': 'SERVICIO DE VIVIENDA Y URBANIZACION VII REGION'},
#   {'CodigoEmpresa': '6981',
#    'NombreEmpresa': 'SERVICIO DE VIVIENDA Y URBANIZACION X REGION'},
#   {'CodigoEmpresa': '6982',
#    'NombreEmpresa': 'SERVICIO DE VIVIENDA Y URBANIZACION XI REGION'},
#   {'CodigoEmpresa': '225773', 'NombreEmpresa': 'SERVICIO ELECTORAL'},
#   {'CodigoEmpresa': '1723291',
#    'NombreEmpresa': 'SERVICIO LOCAL DE EDUCACION PÚBLICA DE ATACAMA'},
#   {'CodigoEmpresa': '7179', 'NombreEmpresa': 'SERVICIO MEDICO LEGAL'},
#   {'CodigoEmpresa': '7476',
#    'NombreEmpresa': 'SERVICIO NAC DE SALUD HOSPITAL DE PTO CISNES'},
#   {'CodigoEmpresa': '7479',
#    'NombreEmpresa': 'SERVICIO NAC DE SALUD HOSPITAL TRAUMATOLOGICO'},
#   {'CodigoEmpresa': '7289',
#    'NombreEmpresa': 'SERVICIO NACIONAL ARAUCANIA SUR HOSPITAL DR ABRAHAM GODOY PENA LAUTARO'},
#   {'CodigoEmpresa': '6952', 'NombreEmpresa': 'SERVICIO NACIONAL DE ADUANAS'},
#   {'CodigoEmpresa': '6962',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE CAPACITACION Y EMPLEO'},
#   {'CodigoEmpresa': '7210',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE GEOLOGIA Y MINERIA'},
#   {'CodigoEmpresa': '7184',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE LA DISCAPACIDAD'},
#   {'CodigoEmpresa': '6948',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE LA MUJER Y LA EQUIDAD DE GENERO'},
#   {'CodigoEmpresa': '7017', 'NombreEmpresa': 'SERVICIO NACIONAL DE MENORES'},
#   {'CodigoEmpresa': '7033',
#    'NombreEmpresa': 'Servicio Nacional de Pesca VI Región'},
#   {'CodigoEmpresa': '7180',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE PREVENCIÓN Y RESPUESTA ANTE DESASTRES'},
#   {'CodigoEmpresa': '1765960',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE PROTECCIÓN ESPECIALIZADA A LA NIÑEZ Y ADOLESCENCI'},
#   {'CodigoEmpresa': '1468521',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL CARLOS VAN BUREN'},
#   {'CodigoEmpresa': '116754',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE C'},
#   {'CodigoEmpresa': '7340',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE C'},
#   {'CodigoEmpresa': '7399',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE C'},
#   {'CodigoEmpresa': '7480',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE COCHRANE'},
#   {'CodigoEmpresa': '7285',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE COELEMU'},
#   {'CodigoEmpresa': '7332',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE CORONEL'},
#   {'CodigoEmpresa': '7475',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE FLORIDA'},
#   {'CodigoEmpresa': '7402',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE LEBU'},
#   {'CodigoEmpresa': '7481',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE LOTA'},
#   {'CodigoEmpresa': '7459',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE P'},
#   {'CodigoEmpresa': '7335',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE PUERTO AYSEN'},
#   {'CodigoEmpresa': '7287',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE PUERTO OCTAY'},
#   {'CodigoEmpresa': '7470',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE RIO NEGRO'},
#   {'CodigoEmpresa': '7457',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL DE T'},
#   {'CodigoEmpresa': '7465',
#    'NombreEmpresa': 'SERVICIO NACIONAL DE SALUD HOSPITAL PUREN'},
#   {'CodigoEmpresa': '7190', 'NombreEmpresa': 'SERVICIO NACIONAL DE TURISMO'},
#   {'CodigoEmpresa': '7032',
#    'NombreEmpresa': 'SERVICIO NACIONAL DEL ADULTO MAYOR'},
#   {'CodigoEmpresa': '7230',
#    'NombreEmpresa': 'Servicio Nacional del Consumidor - SERNAC'},
#   {'CodigoEmpresa': '7011',
#    'NombreEmpresa': 'SERVICIO NACIONAL DEL PATRIMONIO CULTURAL'},
#   {'CodigoEmpresa': '278907',
#    'NombreEmpresa': 'SERVICIO REGIONAL DE LA VIVIENDA Y URBAN'},
#   {'CodigoEmpresa': '7462',
#    'NombreEmpresa': 'SERVICIO SALUD ARAUCANIA HOSPITAL DE COLLIPULLI'},
#   {'CodigoEmpresa': '7433',
#    'NombreEmpresa': 'SERVICIO SALUD ARAUCANIA NORTE HOSPITAL CURACAUTIN'},
#   {'CodigoEmpresa': '7288',
#    'NombreEmpresa': 'SERVICIO SALUD ARAUCANIA NORTE HOSPITAL VICTORIA'},
#   {'CodigoEmpresa': '7291',
#    'NombreEmpresa': 'SERVICIO SALUD ARAUCANIA SUR HOSPIT DR EDUARDO GONZALEZ GALENO CUNCO'},
#   {'CodigoEmpresa': '7048',
#    'NombreEmpresa': 'SERVICIO SALUD ARAUCANIA SUR HOSPITAL PITRUFQUEN'},
#   {'CodigoEmpresa': '7062',
#    'NombreEmpresa': 'SERVICIO SALUD ARAUCANIA SUR HOSPITAL TOLTEN'},
#   {'CodigoEmpresa': '7414',
#    'NombreEmpresa': 'SERVICIO SALUD ATACAMA HOSPITAL DE HUASCO'},
#   {'CodigoEmpresa': '7388',
#    'NombreEmpresa': 'SERVICIO SALUD BIO BIO HOSPITAL NACIMIENTO'},
#   {'CodigoEmpresa': '7323',
#    'NombreEmpresa': 'SERVICIO SALUD COQUIMBO HOSP DE SALAMANC'},
#   {'CodigoEmpresa': '7104', 'NombreEmpresa': 'SERVICIO SALUD DEL RELONCAVI'},
#   {'CodigoEmpresa': '7029',
#    'NombreEmpresa': 'SERVICIO SALUD METROPOLITANO OCCIDENTE'},
#   {'CodigoEmpresa': '7383',
#    'NombreEmpresa': 'SERVICIO SALUD OCCIDENTE HOSPITAL DR FELIX BULNES CERDA'},
#   {'CodigoEmpresa': '7446',
#    'NombreEmpresa': 'SERVICIO SALUD TALCAHUANO HOSPITAL PENCO-LIRQUEN'},
#   {'CodigoEmpresa': '7153',
#    'NombreEmpresa': 'SERVICIO SALUD VINA DEL MAR QUILLOTA'},
#   {'CodigoEmpresa': '6964',
#    'NombreEmpresa': 'SERVIU REGION DE MAGALLANES Y DE LA ANTARTICA CHILENA'},
#   {'CodigoEmpresa': '7333',
#    'NombreEmpresa': 'Subdirección del Ambiente Servicio de Salud Thno.'},
#   {'CodigoEmpresa': '7065', 'NombreEmpresa': 'Subsecretaría de Aviación'},
#   {'CodigoEmpresa': '7036', 'NombreEmpresa': 'Subsecretaría de Carabineros'},
#   {'CodigoEmpresa': '1689493',
#    'NombreEmpresa': 'SUBSECRETARIA DE CIENCIA, TECNOLOGIA, CONOCIMIENTO E INNOVACION'},
#   {'CodigoEmpresa': '7081',
#    'NombreEmpresa': 'SUBSECRETARIA DE DESARROLLO REGIONAL Y ADMINISTRATIVO'},
#   {'CodigoEmpresa': '7078',
#    'NombreEmpresa': 'SUBSECRETARIA DE ECONOMIA Y EMPRESAS DE MENOR TAMANO'},
#   {'CodigoEmpresa': '1155673', 'NombreEmpresa': 'SUBSECRETARIA DE ENERGIA'},
#   {'CodigoEmpresa': '7217',
#    'NombreEmpresa': 'Subsecretaría de Investigaciones'},
#   {'CodigoEmpresa': '7359',
#    'NombreEmpresa': 'SUBSECRETARÍA DE LAS CULTURAS Y LAS ARTES'},
#   {'CodigoEmpresa': '7221', 'NombreEmpresa': 'Subsecretaría de Marina'},
#   {'CodigoEmpresa': '7211',
#    'NombreEmpresa': 'SUBSECRETARIA DE PESCA Y ACUICULTURA'},
#   {'CodigoEmpresa': '7191',
#    'NombreEmpresa': 'SUBSECRETARIA DE PREVISION SOCIAL'},
#   {'CodigoEmpresa': '1674041',
#    'NombreEmpresa': 'SUBSECRETARIA DE RELACIONES ECONOMICAS INTERNACIONALES'},
#   {'CodigoEmpresa': '7227',
#    'NombreEmpresa': 'SUBSECRETARIA DE RELACIONES EXTERIORES'},
#   {'CodigoEmpresa': '7079', 'NombreEmpresa': 'SUBSECRETARIA DE SALUD PUBLICA'},
#   {'CodigoEmpresa': '6947',
#    'NombreEmpresa': 'SUBSECRETARIA DE SERVICIOS SOCIALES'},
#   {'CodigoEmpresa': '6934',
#    'NombreEmpresa': 'SUBSECRETARIA DE TELECOMUNICACIONES'},
#   {'CodigoEmpresa': '7007', 'NombreEmpresa': 'SUBSECRETARIA DE TRANSPORTES'},
#   {'CodigoEmpresa': '6944', 'NombreEmpresa': 'SUBSECRETARIA DEL INTERIOR'},
#   {'CodigoEmpresa': '1198788',
#    'NombreEmpresa': 'SUBSECRETARIA DEL MEDIO AMBIENTE'},
#   {'CodigoEmpresa': '7189',
#    'NombreEmpresa': 'SUBSECRETARIA DEL MINISTERIO DE AGRICULT'},
#   {'CodigoEmpresa': '6958',
#    'NombreEmpresa': 'SUBSECRETARIA DEL MINISTERIO DE EDUCACION PUBLICA'},
#   {'CodigoEmpresa': '6943',
#    'NombreEmpresa': 'SUBSECRETARIA DEL MINISTERIO DE HACIENDA'},
#   {'CodigoEmpresa': '7080',
#    'NombreEmpresa': 'SUBSECRETARIA DEL MINISTERIO DE JUSTICIA'},
#   {'CodigoEmpresa': '6951',
#    'NombreEmpresa': 'SUBSECRETARIA DEL MINISTERIO DE LA VIVIENDA Y URBANISMO'},
#   {'CodigoEmpresa': '7018',
#    'NombreEmpresa': 'SUBSECRETARIA DEL MINISTERIO DE MINERIA'},
#   {'CodigoEmpresa': '6939', 'NombreEmpresa': 'SUBSECRETARIA DEL TRABAJO'},
#   {'CodigoEmpresa': '128260',
#    'NombreEmpresa': 'SUPERINTENDENCIA DE CASINOS DE JUEGO'},
#   {'CodigoEmpresa': '7232',
#    'NombreEmpresa': 'SUPERINTENDENCIA DE ELECTRICIDAD Y COMBUSTIBLES'},
#   {'CodigoEmpresa': '7181',
#    'NombreEmpresa': 'SUPERINTENDENCIA DE INSOLVENCIA Y REEMPRENDIMIENTO'},
#   {'CodigoEmpresa': '93096', 'NombreEmpresa': 'SUPERINTENDENCIA DE PENSIONES'},
#   {'CodigoEmpresa': '6930', 'NombreEmpresa': 'SUPERINTENDENCIA DE SALUD'},
#   {'CodigoEmpresa': '7114',
#    'NombreEmpresa': 'SUPERINTENDENCIA DE SEGURIDAD SOCIAL'},
#   {'CodigoEmpresa': '7192',
#    'NombreEmpresa': 'SUPERINTENDENCIA DE SERVICIOS SANITARIOS'},
#   {'CodigoEmpresa': '6956',
#    'NombreEmpresa': 'TESORERIA GENERAL DE LA REPUBLICA'},
#   {'CodigoEmpresa': '1083414',
#    'NombreEmpresa': 'UNIDAD ADMINISTRADORA DE LOS TRIBUNALES TRIBUTARIOS Y ADUANEROS'},
#   {'CodigoEmpresa': '85017', 'NombreEmpresa': 'UNIDAD DE ANALISIS FINANCIERO'},
#   {'CodigoEmpresa': '7254', 'NombreEmpresa': 'UNIVERSIDAD ARTURO PRAT'},
#   {'CodigoEmpresa': '130585', 'NombreEmpresa': 'UNIVERSIDAD DE ANTOFAGASTA'},
#   {'CodigoEmpresa': '103916', 'NombreEmpresa': 'UNIVERSIDAD DE ATACAMA'},
#   {'CodigoEmpresa': '7251', 'NombreEmpresa': 'UNIVERSIDAD DE CHILE'},
#   {'CodigoEmpresa': '277559', 'NombreEmpresa': 'UNIVERSIDAD DE LA FRONTERA'},
#   {'CodigoEmpresa': '7319', 'NombreEmpresa': 'UNIVERSIDAD DE LA SERENA'},
#   {'CodigoEmpresa': '266724', 'NombreEmpresa': 'UNIVERSIDAD DE LOS LAGOS'},
#   {'CodigoEmpresa': '257227', 'NombreEmpresa': 'UNIVERSIDAD DE MAGALLANES'},
#   {'CodigoEmpresa': '130972',
#    'NombreEmpresa': 'UNIVERSIDAD DE PLAYA ANCHA DE CIENCIAS DE LA EDUCACION'},
#   {'CodigoEmpresa': '212299',
#    'NombreEmpresa': 'UNIVERSIDAD DE SANTIAGO DE CHILE'},
#   {'CodigoEmpresa': '7147', 'NombreEmpresa': 'UNIVERSIDAD DE TALCA'},
#   {'CodigoEmpresa': '204439', 'NombreEmpresa': 'UNIVERSIDAD DE TARAPACA'},
#   {'CodigoEmpresa': '96996', 'NombreEmpresa': 'UNIVERSIDAD DE VALPARAISO'},
#   {'CodigoEmpresa': '99805', 'NombreEmpresa': 'UNIVERSIDAD DEL BIO BIO'},
#   {'CodigoEmpresa': '164268',
#    'NombreEmpresa': 'UNIVERSIDAD METROPOLITANA DE CIENCIAS DE LA EDUCACION'},
#   {'CodigoEmpresa': '126109',
#    'NombreEmpresa': 'UNIVERSIDAD TECNOLOGICA METROPOLITANA'},
#   {'CodigoEmpresa': '7438', 'NombreEmpresa': 'Zona Franca de Iquique'}]}

# %%
df_empresas
# Out:
#     CodigoEmpresa                                      NombreEmpresa
# 0            7086  AGENCIA CHILENA DE COOPERACION INTERNACIONAL P...
# 1         1224636           AGENCIA CHILENA DE EFICIENCIA ENERGETICA
# 2            7193    AGENCIA DE PROMOCION DE LA INVERSION EXTRANJERA
# 3            7212                   Agencia Nacional de Inteligencia
# 4         1824441  ASOCIACION DE MUNICIPIOS METROPOLITANOS PARA L...
# ..            ...                                                ...
# 895         96996                          UNIVERSIDAD DE VALPARAISO
# 896         99805                            UNIVERSIDAD DEL BIO BIO
# 897        164268  UNIVERSIDAD METROPOLITANA DE CIENCIAS DE LA ED...
# 898        126109              UNIVERSIDAD TECNOLOGICA METROPOLITANA
# 899          7438                             Zona Franca de Iquique
#
# [900 rows x 2 columns]
